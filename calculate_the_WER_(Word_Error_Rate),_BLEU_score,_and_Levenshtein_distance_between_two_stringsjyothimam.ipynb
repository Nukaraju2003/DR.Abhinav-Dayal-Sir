# %% [markdown]
# <a href="https://colab.research.google.com/github/Nukaraju2003/DR.Abhinav-Dayal-Sir/blob/main/calculate_the_WER_(Word_Error_Rate)%2C_BLEU_score%2C_and_Levenshtein_distance_between_two_stringsjyothimam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# Example usage:
textwhispersmall = "Tell me about yourself. Good afternoon ma'am. I am Radha Laveerabhargavi from West Dakota Valley and currently I am pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in SESI junior college with 96% and I completed my 10th with 93% in Nagarjuna school. Coming to my family, my family includes my father who is a horticulturist, my mother who is a homemaker, and my sister currently pursuing her intermediate and I love playing badminton. I have good knowledge in Java and Python and I'm also interested in machine learning. I have completed two decent projects called screen recording application using Python and exploratory data analysis on engineering placements. What is your role in projects? My role is developing the application member. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and Open CD. Technology in the sense you should mention which programming language you have used. I have used Python language. Is the growing of technology good for humans or not? Yes ma'am, growing of technology is good for humans in one way and in other ways, it leads to some consequences like data security is not possible if we have more technology. And you said that you are interested in machine learning. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities ma'am. But in some way, it leads to unemployment. Okay. Would you prefer hard work or smart work? I prefer both which are suitable for the condition. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work ma'am. But in multitasking we use smart work. What made you choose the IT sector? IT sector is growing ma'am. Every day we have new technology and we can learn new things. Are you interested for relocation of your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOPs is an object-oriented programming which we can store the data in the form of objects and classes and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now I don't know the exact answer. I have only, I have no, only the basics of C language. What is a static variable? Static variable can be used for three types. It can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed and if we use static for a method, the method cannot be overridden and if we use it as a class, the class cannot be. What are different aggregation functions in SQL? Max min sum count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? I do not know. Explain about inheritance and its types. Inheritance is the situation when child class inherits the properties from the parent class. Inheritance types are multiple inheritance, multilevel inheritance, single inheritance, hybrid inheritance. Whether Python support all types of inheritance like Java. What is a constructor? Constructor is nothing but the instance of class which can have the same name of class and it does not contain any return type. Okay. Can you explain the logic for string reverse, implementation of string reverse? Yes ma'am. It is like minus index map we use, call and call and minus 1. Explain polymorphism with real life examples. Polymorphism means having many forms map. For example, water map, water has many forms, it is like solid, gas and liquid. What is the use of final keyword in Java? What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional model. Do you have any role model? I have a role model Abdul Kalab. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay fine."
textgoldstandard = "Tell me about yourself. Good afternoon, ma'am. I'm Thadala Veerabargiri from West Godavari. And Currently, I'm pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father, who is a horticulturist, my mother, who is a homemaker, and my sister currently pursuing her intermediate. And I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two descent projects called screen recording application using Python and exploratory data analysis on engineering placements.Currently, What is your role in projects? My role is developing the application Ma'am. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCV. Technology in the sense you should mention which programming language you have used. I have used Python Ma'am. Okay, is growing of technology good for humans or not? Yes ma'am, the growing of technology is good for humans in one way, and in other ways, it leads to some consequences, ma'am, like data security is not possible if we have more technology, ma'am. And you said that you are interested in machine learning. Yes, ma'am. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities, ma'am. But in some way, it leads to unemployment, ma'am. OK. Would you prefer hard work or smart work? I prefer both which is suitable to the condition Ma'am. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work, ma'am. But in multitasking, we use smart work. What made you to choose the IT sector? The IT sector is growing, ma'am. Every day we have new technology, and we can learn new things. Are you interested for relocation for your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is an object-oriented programming which we can store the data in the form of objects and classes, and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now, I do not know the exact answer. I have only known the basics of C Ma'am. What is a static variable? Static variable can be used for 3 types, it can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed, and if we use static for a method, the method cannot be overridden, and if we use it as a class, the class cannot be inherited. What are different aggregation functions in SQL? Max, min, sum, count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword.As!,  Desc, oke. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when the child class inherits the properties from the parent class. Inheritance types are multiple inheritances, multilevel inheritances, single inheritances, hybrid inheritances. Whether Python supports all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but an instance of a class that can have the same name of the class and it does not contain any return type. Ok. Can you explain me the logic for string reverse, implementation of string reverse? Yes ma'am. in python we use index for the string reverse Ma'am. It is like minus index, ma'am, we use column, column minus 1. Explain polymorphism with real-life examples. Polymorphism means having many forms, ma'am. For example, water, ma'am, water has many forms, it is like solid, gas, and liquid. What is the use of the final keyword in Java? don't know Ma'am. What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have a role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."

hypothesis = textwhispersmall
reference = textgoldstandard

def calculate_wer(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    distance = nltk.edit_distance(hypothesis_words, reference_words)
    wer = distance / len(reference_words)
    return wer

def calculate_bleu(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    weights = tuple([1.0 / len(reference_words)] * len(reference_words))
    bleu = sentence_bleu([reference_words], hypothesis_words, weights=weights)
    return bleu

def calculate_levenshtein(hypothesis, reference):
    distance = nltk.edit_distance(hypothesis, reference)
    return distance

wer = calculate_wer(hypothesis, reference)
bleu = calculate_bleu(hypothesis, reference)
levenshtein = calculate_levenshtein(hypothesis, reference)

print("WER:", wer)
print("BLEU:", bleu)
print("Levenshtein distance:", levenshtein)
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 43-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 44-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 45-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# ...

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# Example usage:
textwhispermedium = "Tell me about yourself. Good afternoon ma'am. I am Radha Laveerabhargavi from West Dakota Valley and currently, I am pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in SESI junior college with 96% and I completed my 10th with 93% in Nagarjuna school. Coming to my family, my family includes my father who is a horticulturist, my mother who is a homemaker, and my sister currently pursuing her intermediate and I love playing badminton. I have good knowledge in Java and Python and I'm also interested in machine learning. I have completed two decent projects called screen recording application using Python and exploratory data analysis on engineering placements. What is your role in projects? My role is developing the application member. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and Open CD. Technology in the sense you should mention which programming language you have used. I have used Python language. Is the growing of technology good for humans or not? Yes ma'am, growing of technology is good for humans in one way and in other ways, it leads to some consequences like data security is not possible if we have more technology. And you said that you are interested in machine learning. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities ma'am. But in some way, it leads to unemployment. Okay. Would you prefer hard work or smart work? I prefer both which are suitable for the condition. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work ma'am. But in multitasking we use smart work. What made you choose the IT sector? IT sector is growing ma'am. Every day we have new technology and we can learn new things. Are you interested for relocation of your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOPs is an object-oriented programming which we can store the data in the form of objects and classes and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now I don't know the exact answer. I have only, I have no, only the basics of C language. What is a static variable? Static variable can be used for three types. It can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed and if we use static for a method, the method cannot be overridden and if we use it as a class, the class cannot be. What are different aggregation functions in SQL? Max min sum count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? I do not know. Explain about inheritance and its types. Inheritance is the situation when child class inherits the properties from the parent class. Inheritance types are multiple inheritance, multilevel inheritance, single inheritance, hybrid inheritance. Whether Python support all types of inheritance like Java. What is a constructor? Constructor is nothing but the instance of class which can have the same name of class and it does not contain any return type. Okay. Can you explain the logic for string reverse, implementation of string reverse? Yes ma'am. It is like minus index map we use, call and call and minus 1. Explain polymorphism with real life examples. Polymorphism means having many forms map. For example, water map, water has many forms, it is like solid, gas and liquid. What is the use of final keyword in Java? What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional model. Do you have any role model? I have a role model Abdul Kalab. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay fine."
textgoldstandard = "Tell me about yourself. Good afternoon, ma'am. I'm Thadala Veerabargiri from West Godavari. And Currently, I'm pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father, who is a horticulturist, my mother, who is a homemaker, and my sister currently pursuing her intermediate. And I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two descent projects called screen recording application using Python and exploratory data analysis on engineering placements.Currently, What is your role in projects? My role is developing the application Ma'am. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCV. Technology in the sense you should mention which programming language you have used. I have used Python Ma'am. Okay, is growing of technology good for humans or not? Yes ma'am, the growing of technology is good for humans in one way, and in other ways, it leads to some consequences, ma'am, like data security is not possible if we have more technology, ma'am. And you said that you are interested in machine learning. Yes, ma'am. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities, ma'am. But in some way, it leads to unemployment, ma'am. OK. Would you prefer hard work or smart work? I prefer both which is suitable to the condition Ma'am. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work, ma'am. But in multitasking, we use smart work. What made you to choose the IT sector? The IT sector is growing, ma'am. Every day we have new technology, and we can learn new things. Are you interested for relocation for your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is an object-oriented programming which we can store the data in the form of objects and classes, and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now, I do not know the exact answer. I have only known the basics of C Ma'am. What is a static variable? Static variable can be used for 3 types, it can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed, and if we use static for a method, the method cannot be overridden, and if we use it as a class, the class cannot be inherited. What are different aggregation functions in SQL? Max, min, sum, count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword.As!,  Desc, oke. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when the child class inherits the properties from the parent class. Inheritance types are multiple inheritances, multilevel inheritances, single inheritances, hybrid inheritances. Whether Python supports all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but an instance of a class that can have the same name of the class and it does not contain any return type. Ok. Can you explain me the logic for string reverse, implementation of string reverse? Yes ma'am. in python we use index for the string reverse Ma'am. It is like minus index, ma'am, we use column, column minus 1. Explain polymorphism with real-life examples. Polymorphism means having many forms, ma'am. For example, water, ma'am, water has many forms, it is like solid, gas, and liquid. What is the use of the final keyword in Java? don't know Ma'am. What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have a role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."
hypothesis = textwhispermedium
reference = textgoldstandard

def calculate_wer(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    distance = nltk.edit_distance(hypothesis_words, reference_words)
    wer = distance / len(reference_words)
    return wer

def calculate_bleu(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    weights = tuple([1.0 / len(reference_words)] * len(reference_words))
    bleu = sentence_bleu([reference_words], hypothesis_words, weights=weights)
    return bleu

def calculate_levenshtein(hypothesis, reference):
    distance = nltk.edit_distance(hypothesis, reference)
    return distance

wer = calculate_wer(hypothesis, reference)
bleu = calculate_bleu(hypothesis, reference)
levenshtein = calculate_levenshtein(hypothesis, reference)

print("WER:", wer)
print("BLEU:", bleu)
print("Levenshtein distance:", levenshtein)
# Out:
# WER: 0.1724137931034483
# BLEU: 1.5253619858807739e-292
# Levenshtein distance: 451

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# Example usage:
textwhisperlarge = "Tell me about yourself. Good afternoon, ma'am. I am Tadala Veera Bhargavi from West Godavari. Currently, I am pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father who is a horticulturist, my mother who is a homemaker, and my sister currently pursuing her intermediate, and I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two decent projects called screen recording application using Python and exploratory data analysis on engineering placements. What is your role in projects? My role is developing the application. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCD. Technology in the sense you should mention which programming language you have used. I have used Python and this. Okay, is growing of technology is good for human or not? Yes ma'am, growing of technology is good for human in one way and in other way it leads to some consequences ma'am like data security is not possible if we have more technology ma'am. And you said that you are interested in machine learning. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities ma'am. But in some way it leads to unemployment ma'am. Okay. Would you prefer hard work or smart work? I prefer both which is suitable to condition try to elaborate it with an example at least like if we want to achieve something we need some patience and in that time, we need hard work ma'am but in multitasking we use smart work what made you to choose IT sector IT sector is growing ma'am everything. Every day we have new technology and we can learn new things. Are you interested for relocation of your job? Yes ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is Object Oriented Programming which we can store the data in the form of objects and classes. And it has four main principles like abstraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now I don't know the exact answer. I have only, I have know only the basics of C language. Okay, what is a static variable? Static variable can be used for three types. It can be used for class, method, and variable. If we use static for variable, the variable can't be changed. And if we use static for method, the method can't be overridden. And if we use it as a class, the class can't be inherited. What are different aggregation functions in SQL? Max, min, sum, count Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by By using a keyword What is normalization? Normalization is dividing tables into small tables which can be in decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when child class inherits the properties from the parent class. Inheritance types are multiple inheritance, multi-level inheritance, single inheritance, hybrid inheritance. Whether python support all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but a instance of class which can have same name of class and it does not contain any written type. Okay. Can you explain me the logic for string reverse, implementation of string reverse? Yes, ma'am. In Python, we use... index for the string reverse it's like minus index ma'am we use column column minus one explain polymorphism with real life examples polymorphism means having many forms ma'am for example water ma'am water has many forms it's like solid gas and liquid ok what is the use of final keyword in java What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."

textgoldstandard = "Tell me about yourself. Good afternoon, ma'am. I'm Thadala Veerabargiri from West Godavari. And Currently, I'm pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father, who is a horticulturist, my mother, who is a homemaker, and my sister currently pursuing her intermediate. And I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two descent projects called screen recording application using Python and exploratory data analysis on engineering placements.Currently, What is your role in projects? My role is developing the application Ma'am. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCV. Technology in the sense you should mention which programming language you have used. I have used Python Ma'am. Okay, is growing of technology good for humans or not? Yes ma'am, the growing of technology is good for humans in one way, and in other ways, it leads to some consequences, ma'am, like data security is not possible if we have more technology, ma'am. And you said that you are interested in machine learning. Yes, ma'am. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities, ma'am. But in some way, it leads to unemployment, ma'am. OK. Would you prefer hard work or smart work? I prefer both which is suitable to the condition Ma'am. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work, ma'am. But in multitasking, we use smart work. What made you to choose the IT sector? The IT sector is growing, ma'am. Every day we have new technology, and we can learn new things. Are you interested for relocation for your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is an object-oriented programming which we can store the data in the form of objects and classes, and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now, I do not know the exact answer. I have only known the basics of C Ma'am. What is a static variable? Static variable can be used for 3 types, it can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed, and if we use static for a method, the method cannot be overridden, and if we use it as a class, the class cannot be inherited. What are different aggregation functions in SQL? Max, min, sum, count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword.As!,  Desc, oke. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when the child class inherits the properties from the parent class. Inheritance types are multiple inheritances, multilevel inheritances, single inheritances, hybrid inheritances. Whether Python supports all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but an instance of a class that can have the same name of the class and it does not contain any return type. Ok. Can you explain me the logic for string reverse, implementation of string reverse? Yes ma'am. in python we use index for the string reverse Ma'am. It is like minus index, ma'am, we use column, column minus 1. Explain polymorphism with real-life examples. Polymorphism means having many forms, ma'am. For example, water, ma'am, water has many forms, it is like solid, gas, and liquid. What is the use of the final keyword in Java? don't know Ma'am. What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have a role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."
hypothesis = textwhisperlarge
reference = textgoldstandard

def calculate_wer(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    distance = nltk.edit_distance(hypothesis_words, reference_words)
    wer = distance / len(reference_words)
    return wer

def calculate_bleu(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    weights = tuple([1.0 / len(reference_words)] * len(reference_words))
    bleu = sentence_bleu([reference_words], hypothesis_words, weights=weights)
    return bleu

def calculate_levenshtein(hypothesis, reference):
    distance = nltk.edit_distance(hypothesis, reference)
    return distance

wer = calculate_wer(hypothesis, reference)
bleu = calculate_bleu(hypothesis, reference)
levenshtein = calculate_levenshtein(hypothesis, reference)

print("WER:", wer)
print("BLEU:", bleu)
print("Levenshtein distance:", levenshtein)
# Out:
# WER: 0.17364532019704434
# BLEU: 3.878324181639616e-289
# Levenshtein distance: 306

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# Example usage:
textwhisperlarge_v2 = "Tell me about yourself. Good afternoon, ma'am. I'm Thadala Veerabargiri from West Godavari. Currently, I'm pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father, who is a horticulturist, my mother, who is a homemaker, and my sister currently pursuing her intermediate. And I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two decent projects called screen recording application using Python and exploratory data analysis on engineering placements. What is your role in projects? My role is developing the application map. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCD. Technology in the sense you should mention which programming language you have used. I have used Python. Okay, is the growth of technology good for humans or not? Yes ma'am, the growth of technology is good for humans in one way, and in other ways, it leads to some consequences, ma'am, like data security is not possible if we have more technology, ma'am. And you said that you are interested in machine learning. Yes, ma'am. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities, ma'am. But in some way, it leads to unemployment, ma'am. OK. Would you prefer hard work or smart work? I prefer both which are suitable for the condition. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work, ma'am. But in multitasking, we use smart work. What made you choose the IT sector? The IT sector is growing, ma'am. Every day we have new technology, and we can learn new things. Are you interested in relocation for your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is an object-oriented programming which we can store the data in the form of objects and classes, and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now, I do not know the exact answer. I have only known the basics of C language. What is a static variable? Static variable can be used for 3 types, it can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed, and if we use static for a method, the method cannot be overridden, and if we use it as a class, the class cannot be inherited. What are different aggregation functions in SQL? Max, min, sum, count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when the child class inherits the properties from the parent class. Inheritance types are multiple inheritances, multilevel inheritances, single inheritances, hybrid inheritances. Whether Python supports all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but an instance of a class that can have the same name of the class and it does not contain any return type. Ok. Can you explain me the logic for string reverse, implementation of string reverse? Yes ma'am. It is like minus index, ma'am, we use column, column minus 1. Explain polymorphism with real-life examples. Polymorphism means having many forms, ma'am. For example, water, ma'am, water has many forms, it is like solid, gas, and liquid. What is the use of the final keyword in Java? What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have a role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."
textgoldstandard = "Tell me about yourself. Good afternoon, ma'am. I'm Thadala Veerabargiri from West Godavari. And Currently, I'm pursuing my B.Tech final year in Vishnu Institute of Technology with CGPA 9.12. I have completed my intermediate in Sasi Junior College with 96% and I completed my 10th with 93% in Nagarjuna School. Coming to my family, my family includes my father, who is a horticulturist, my mother, who is a homemaker, and my sister currently pursuing her intermediate. And I love playing badminton. I have good knowledge in Java and Python, and I'm also interested in machine learning. I have completed two descent projects called screen recording application using Python and exploratory data analysis on engineering placements.Currently, What is your role in projects? My role is developing the application Ma'am. Like what technologies you have used for the development of your projects? I have used libraries like NumPy, Pandas, and OpenCV. Technology in the sense you should mention which programming language you have used. I have used Python Ma'am. Okay, is growing of technology good for humans or not? Yes ma'am, the growing of technology is good for humans in one way, and in other ways, it leads to some consequences, ma'am, like data security is not possible if we have more technology, ma'am. And you said that you are interested in machine learning. Yes, ma'am. Like every person can be replaced by an artificial machine. Then what is your opinion on that? It is a boon for people having any disabilities, ma'am. But in some way, it leads to unemployment, ma'am. OK. Would you prefer hard work or smart work? I prefer both which is suitable to the condition Ma'am. Try to elaborate it with an example at least. Like if we want to achieve something we need some patience and in that time, we need hard work, ma'am. But in multitasking, we use smart work. What made you to choose the IT sector? The IT sector is growing, ma'am. Every day we have new technology, and we can learn new things. Are you interested for relocation for your job? Yes, ma'am. Are you comfortable with rotational shifts like day shift and night shift? Yes, ma'am. I will be comfortable with rotational shifts. Okay, let's move with the technical side. Explain about OOP concepts. OOP is an object-oriented programming which we can store the data in the form of objects and classes, and it has four main principles like extraction, polymorphism, inheritance, and encapsulation. What is the difference between union and structure in C language? Right now, I do not know the exact answer. I have only known the basics of C Ma'am. What is a static variable? Static variable can be used for 3 types, it can be used for class, method, and variable. If we use static for a variable, the variable cannot be changed, and if we use static for a method, the method cannot be overridden, and if we use it as a class, the class cannot be inherited. What are different aggregation functions in SQL? Max, min, sum, count. Can you explain about descending order in SQL? How we can implement descending order? We can implement by using it in group by. By using a keyword.As!,  Desc, oke. What is normalization? Normalization is dividing tables into small tables which can be decomposed form. What is data redundancy? Data redundancy is having multiple copies. What is the second normal form? Explain about inheritance and its types. Inheritance is the situation when the child class inherits the properties from the parent class. Inheritance types are multiple inheritances, multilevel inheritances, single inheritances, hybrid inheritances. Whether Python supports all types of inheritance like Java? Java does not support all types of inheritance, ma'am, but Python supports all types of inheritance. What is a constructor? Constructor is nothing but an instance of a class that can have the same name of the class and it does not contain any return type. Ok. Can you explain me the logic for string reverse, implementation of string reverse? Yes ma'am. in python we use index for the string reverse Ma'am. It is like minus index, ma'am, we use column, column minus 1. Explain polymorphism with real-life examples. Polymorphism means having many forms, ma'am. For example, water, ma'am, water has many forms, it is like solid, gas, and liquid. What is the use of the final keyword in Java? don't know Ma'am. What is a strong number? Strong number means the sum of factorial of given digits of a number is equal to the given number. Where do you want to watch yourself in the next 5 years? I want to become a software professional. Do you have any role model? I have a role model Abdul Kalam. Why? Because from childhood he faced many challenges and although he can be successful in his life. Okay, fine."

hypothesis = textwhisperlarge_v2
reference = textgoldstandard

def calculate_wer(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    distance = nltk.edit_distance(hypothesis_words, reference_words)
    wer = distance / len(reference_words)
    return wer

def calculate_bleu(hypothesis, reference):
    hypothesis_words = hypothesis.split()
    reference_words = reference.split()

    weights = tuple([1.0 / len(reference_words)] * len(reference_words))
    bleu = sentence_bleu([reference_words], hypothesis_words, weights=weights)
    return bleu

def calculate_levenshtein(hypothesis, reference):
    distance = nltk.edit_distance(hypothesis, reference)
    return distance

wer = calculate_wer(hypothesis, reference)
bleu = calculate_bleu(hypothesis, reference)
levenshtein = calculate_levenshtein(hypothesis, reference)

print("WER:", wer)
print("BLEU:", bleu)
print("Levenshtein distance:", levenshtein)
# Out:
# WER: 0.04064039408866995
# BLEU: 9.447302441988254e-258
# Levenshtein distance: 146
